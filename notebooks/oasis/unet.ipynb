# %% [markdown]
# ## 데이터 준비

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! tar -xvf /content/drive/MyDrive/project_2/MSD/Task04_Hippocampus.tar
# Out:
# ./._Task04_Hippocampus
# Task04_Hippocampus/
# Task04_Hippocampus/._.DS_Store
# Task04_Hippocampus/.DS_Store
# Task04_Hippocampus/._labelsTr
# Task04_Hippocampus/labelsTr/
# Task04_Hippocampus/._imagesTr
# Task04_Hippocampus/imagesTr/
# Task04_Hippocampus/._imagesTs
# Task04_Hippocampus/imagesTs/
# Task04_Hippocampus/._dataset.json
# Task04_Hippocampus/dataset.json
# Task04_Hippocampus/imagesTs/hippocampus_267.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_379.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_208.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_275.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_131.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_140.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_076.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_115.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_168.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_119.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_021.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_121.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_388.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_384.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_284.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_005.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_078.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_066.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_117.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_009.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_214.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_369.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_377.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_306.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_206.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_218.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_365.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_187.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_241.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_013.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_113.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_062.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_137.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_054.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_129.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_029.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_392.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_191.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_183.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_357.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_202.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_273.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_255.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_081.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_247.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_347.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_324.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_271.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_371.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_312.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_200.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_103.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_072.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_111.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_139.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_027.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_382.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_069.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_018.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_118.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_030.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_153.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_122.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_022.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_196.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_342.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_278.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_266.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_209.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_198.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_186.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_240.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_323.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_315.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_364.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_307.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_167.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_079.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_179.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_116.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_016.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_043.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_120.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_151.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_285.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_272.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_211.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_339.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_239.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_344.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_256.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_082.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_182.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_348.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_028.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_128.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_055.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_281.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_147.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_047.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_293.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_159.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_059.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_071.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_112.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_012.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_063.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_100.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_391.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_291.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_283.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_134.nii.gz
# Task04_Hippocampus/imagesTs/._hippocampus_002.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_002.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_061.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_110.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_010.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_073.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_313.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_213.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_270.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_201.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_262.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_362.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_080.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_237.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_254.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_192.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_258.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_346.nii.gz
# Task04_Hippocampus/imagesTs/hippocampus_246.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_367.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_304.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_204.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_279.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_308.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_375.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_216.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_316.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_089.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_189.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_243.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_343.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_220.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_097.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_320.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_197.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_351.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_251.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_185.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_332.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_232.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_298.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_152.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_052.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_386.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_286.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_040.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_294.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_023.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_394.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_123.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_176.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_015.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_068.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_019.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_164.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_064.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_107.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_007.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_296.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_288.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_042.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_142.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_133.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_033.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_150.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_050.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_105.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_178.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_166.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_017.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_109.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_074.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_174.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_314.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_269.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_277.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_318.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_265.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_330.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_087.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_230.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_199.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_099.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_353.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_253.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_222.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_095.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_322.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_195.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_341.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_070.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_170.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_101.nii.gz
# Task04_Hippocampus/imagesTr/._hippocampus_001.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_001.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_162.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_380.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_037.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_280.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_154.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_058.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_158.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_292.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_025.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_125.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_046.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_146.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_226.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_091.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_326.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_245.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_345.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_238.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_338.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_349.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_249.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_334.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_083.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_234.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_257.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_302.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_361.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_261.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_210.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_310.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_373.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_355.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_328.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_228.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_181.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_336.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_236.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_259.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_359.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_224.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_093.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_193.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_212.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_363.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_263.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_300.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_160.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_060.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_003.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_172.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_011.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_044.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_144.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_039.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_290.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_390.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_127.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_156.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_056.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_148.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_048.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_135.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_035.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_282.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_169.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_114.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_014.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_177.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_077.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_006.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_106.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_065.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_165.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_287.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_130.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_387.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_053.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_299.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_295.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_141.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_041.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_321.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_221.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_096.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_242.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_188.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_088.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_084.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_233.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_184.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_333.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_250.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_350.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_378.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_205.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_305.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_366.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_317.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_217.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_374.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_274.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_309.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_252.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_352.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_098.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_231.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_331.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_340.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_194.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_223.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_094.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_376.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_276.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_368.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_268.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_215.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_264.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_219.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_319.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_207.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_067.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_004.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_104.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_175.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_075.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_108.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_008.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_143.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_389.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_289.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_297.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_020.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_051.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_132.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_385.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_260.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_360.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_203.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_303.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_372.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_311.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_244.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_327.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_190.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_227.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_090.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_356.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_235.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_335.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_248.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_155.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_036.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_136.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_381.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_393.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_124.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_024.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_171.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_163.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_126.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_026.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_138.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_038.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_145.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_045.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_034.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_383.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_049.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_149.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_057.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_157.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_102.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_161.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_173.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_370.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_301.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_180.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_337.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_229.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_329.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_354.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_325.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_225.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_092.nii.gz
# Task04_Hippocampus/imagesTr/hippocampus_358.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_367.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_304.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_204.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_279.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_308.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_375.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_216.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_316.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_089.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_189.nii.gz
# Task04_Hippocampus/labelsTr/._hippocampus_243.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_243.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_343.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_220.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_097.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_320.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_197.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_351.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_251.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_185.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_332.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_232.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_298.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_152.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_052.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_386.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_286.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_040.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_294.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_023.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_394.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_123.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_176.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_015.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_068.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_019.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_164.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_064.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_107.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_007.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_296.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_288.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_042.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_142.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_133.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_033.nii.gz
# Task04_Hippocampus/labelsTr/._.DS_Store
# Task04_Hippocampus/labelsTr/.DS_Store
# Task04_Hippocampus/labelsTr/hippocampus_150.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_050.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_105.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_178.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_166.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_017.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_109.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_074.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_174.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_314.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_269.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_277.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_318.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_265.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_330.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_087.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_230.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_199.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_099.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_353.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_253.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_222.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_095.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_322.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_195.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_341.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_070.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_170.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_101.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_001.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_162.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_380.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_037.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_280.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_154.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_058.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_158.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_292.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_025.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_125.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_046.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_146.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_226.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_091.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_326.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_245.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_345.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_238.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_338.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_349.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_249.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_334.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_083.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_234.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_257.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_302.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_361.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_261.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_210.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_310.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_373.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_355.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_328.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_228.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_181.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_336.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_236.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_259.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_359.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_224.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_093.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_193.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_212.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_363.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_263.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_300.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_160.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_060.nii.gz
# Task04_Hippocampus/labelsTr/._hippocampus_003.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_003.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_172.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_011.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_044.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_144.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_039.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_290.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_390.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_127.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_156.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_056.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_148.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_048.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_135.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_035.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_282.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_169.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_114.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_014.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_177.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_077.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_006.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_106.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_065.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_165.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_287.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_130.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_387.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_053.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_299.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_295.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_141.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_041.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_321.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_221.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_096.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_242.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_188.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_088.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_084.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_233.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_184.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_333.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_250.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_350.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_378.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_205.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_305.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_366.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_317.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_217.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_374.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_274.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_309.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_252.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_352.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_098.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_231.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_331.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_340.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_194.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_223.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_094.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_376.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_276.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_368.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_268.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_215.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_264.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_219.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_319.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_207.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_067.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_004.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_104.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_175.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_075.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_108.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_008.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_143.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_389.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_289.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_297.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_020.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_051.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_132.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_385.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_260.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_360.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_203.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_303.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_372.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_311.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_244.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_327.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_190.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_227.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_090.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_356.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_235.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_335.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_248.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_155.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_036.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_136.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_381.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_393.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_124.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_024.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_171.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_163.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_126.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_026.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_138.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_038.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_145.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_045.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_034.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_383.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_049.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_149.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_057.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_157.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_102.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_161.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_173.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_370.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_301.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_180.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_337.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_229.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_329.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_354.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_325.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_225.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_092.nii.gz
# Task04_Hippocampus/labelsTr/hippocampus_358.nii.gz

# %%
# !pip -q install nibabel imageio

# %%
import os
from glob import glob

img_paths = sorted(glob("/content/Task04_Hippocampus/imagesTr/*.nii.gz"))
lab_paths = sorted(glob("/content/Task04_Hippocampus/labelsTr/*.nii.gz"))

assert len(img_paths) == len(lab_paths), (len(img_paths), len(lab_paths))

# 파일명 기준 매칭 체크(강력 추천)
def stem(p):
    return os.path.basename(p).replace(".nii.gz","")

img_stems = [stem(p) for p in img_paths]
lab_stems = [stem(p) for p in lab_paths]
assert img_stems == lab_stems, "imagesTr/labelsTr 파일명이 1:1로 정렬/매칭되지 않습니다."

print("cases:", len(img_paths))
print("example:", img_paths[0], lab_paths[0])
# Out:
# cases: 260
# example: /content/Task04_Hippocampus/imagesTr/hippocampus_001.nii.gz /content/Task04_Hippocampus/labelsTr/hippocampus_001.nii.gz

# %%
import numpy as np
import nibabel as nib
import torch
from torch.utils.data import Dataset

class MSDHippocampus3DDataset(Dataset):
    def __init__(self, img_paths, lab_paths, patch_size=(96,96,96), samples_per_volume=4, binary=True):
        self.img_paths = img_paths
        self.lab_paths = lab_paths
        self.patch_size = np.array(patch_size)
        self.samples_per_volume = samples_per_volume
        self.binary = binary

    def __len__(self):
        # 한 볼륨에서 여러 patch를 뽑기 위해 length를 늘려줌
        return len(self.img_paths) * self.samples_per_volume

    def _load_case(self, idx):
        vidx = idx // self.samples_per_volume
        img = np.squeeze(nib.load(self.img_paths[vidx]).get_fdata()).astype(np.float32)
        lab = np.squeeze(nib.load(self.lab_paths[vidx]).get_fdata()).astype(np.int16)
        return img, lab

    # 로버스트 스케일링 같은 영역으로 처리하는 것도 알아보면 좋을 듯??
    def _zscore_nonzero(self, x):
        # 의료영상은 0이 배경인 경우가 많아서 nonzero만으로 z-score
        mask = x != 0
        if mask.sum() < 10:
            # 비정상 케이스 대비
            mean, std = x.mean(), x.std() + 1e-8
            return (x - mean) / std
        mean = x[mask].mean()
        std  = x[mask].std() + 1e-8
        x = (x - mean) / std
        return x

    def _pad_to_patch(self, img, lab):
        H, W, D = img.shape
        ph, pw, pd = map(int, self.patch_size)

        pad_h = max(0, ph - H)
        pad_w = max(0, pw - W)
        pad_d = max(0, pd - D)

        if pad_h or pad_w or pad_d:
            pad = (
                (pad_h//2, pad_h - pad_h//2),
                (pad_w//2, pad_w - pad_w//2),
                (pad_d//2, pad_d - pad_d//2),
            )
            img = np.pad(img, pad, mode="constant", constant_values=0)
            lab = np.pad(lab, pad, mode="constant", constant_values=0)

        return img, lab

    def _random_patch(self, img, lab):
        img, lab = self._pad_to_patch(img, lab)  # ✅ 먼저 패딩

        H, W, D = img.shape
        ph, pw, pd = map(int, self.patch_size)

        fg = np.argwhere(lab > 0)
        use_fg = (len(fg) > 0) and (np.random.rand() < 0.7)

        if use_fg:
            cx, cy, cz = fg[np.random.randint(len(fg))]  # (x,y,z)
        else:
            cx = np.random.randint(0, H)
            cy = np.random.randint(0, W)
            cz = np.random.randint(0, D)

        x1 = int(np.clip(cx - ph//2, 0, H - ph))
        y1 = int(np.clip(cy - pw//2, 0, W - pw))
        z1 = int(np.clip(cz - pd//2, 0, D - pd))

        img_p = img[x1:x1+ph, y1:y1+pw, z1:z1+pd]
        lab_p = lab[x1:x1+ph, y1:y1+pw, z1:z1+pd]

        # ✅ 안전 체크 (디버깅)
        assert img_p.shape == (ph, pw, pd), img_p.shape
        assert lab_p.shape == (ph, pw, pd), lab_p.shape

        return img_p, lab_p

    def __getitem__(self, idx):
        img, lab = self._load_case(idx)
        img = self._zscore_nonzero(img)

        img_p, lab_p = self._random_patch(img, lab)

        if self.binary:
            lab_p = (lab_p > 0).astype(np.int64)
        else:
            lab_p = lab_p.astype(np.int64)

        img_p = np.ascontiguousarray(img_p.astype(np.float32))
        lab_p = np.ascontiguousarray(lab_p)
        # ✅ torch.from_numpy 대신 torch.tensor로 강제 복사
        img_t = torch.tensor(img_p[None, ...], dtype=torch.float32)
        if self.binary :
            lab_t = torch.tensor(lab_p[None, ...], dtype=torch.int64)
        else :
            # ✅ 멀티클래스 라벨은 (H,W,D) long (CrossEntropyLoss 요구사항)
            lab_t = torch.tensor(lab_p, dtype=torch.long)

        return img_t, lab_t

# %%
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader

BATCH = 8

train_imgs, val_imgs, train_labs, val_labs = train_test_split(
    img_paths, lab_paths, test_size=0.2, random_state=42
)

train_ds = MSDHippocampus3DDataset(train_imgs, train_labs, patch_size=(96,96,96), samples_per_volume=4, binary=False)
val_ds   = MSDHippocampus3DDataset(val_imgs,   val_labs,   patch_size=(96,96,96), samples_per_volume=2, binary=False)

train_loader = DataLoader(train_ds, batch_size=BATCH, shuffle=True, num_workers=0, pin_memory=True)
val_loader   = DataLoader(val_ds,   batch_size=BATCH, shuffle=False, num_workers=0, pin_memory=True)

x, y = next(iter(train_loader))
print(x.shape, y.shape, x.dtype, y.unique())
# Out:
# torch.Size([8, 1, 96, 96, 96]) torch.Size([8, 96, 96, 96]) torch.float32 tensor([0, 1, 2])

# %%
import torch.nn.functional as F

def center_crop_to(x, ref):
    # x를 ref의 (D,H,W) 또는 (H,W,D) 공간 크기에 맞춰 center crop
    # 여기선 (B,C,H,W,D) 가정
    _, _, H, W, D = x.shape
    _, _, Hr, Wr, Dr = ref.shape

    dh = (H - Hr) // 2
    dw = (W - Wr) // 2
    dd = (D - Dr) // 2
    return x[:, :, dh:dh+Hr, dw:dw+Wr, dd:dd+Dr]

def match_size(x, ref):
    # x의 공간 크기를 ref에 맞춤: 크면 crop, 작으면 pad
    _, _, H, W, D = x.shape
    _, _, Hr, Wr, Dr = ref.shape

    # crop if larger
    if H > Hr or W > Wr or D > Dr:
        x = center_crop_to(x, ref)

    # pad if smaller
    _, _, H, W, D = x.shape
    pad_h = Hr - H
    pad_w = Wr - W
    pad_d = Dr - D
    if pad_h > 0 or pad_w > 0 or pad_d > 0:
        x = F.pad(
            x,
            (pad_d//2, pad_d - pad_d//2,  # D
             pad_w//2, pad_w - pad_w//2,  # W
             pad_h//2, pad_h - pad_h//2)  # H
        )
    return x

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class DoubleConv3D(nn.Module):
    def __init__(self, in_ch, out_ch):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv3d(in_ch, out_ch, 3, padding=1, bias=False),
            nn.InstanceNorm3d(out_ch),
            nn.LeakyReLU(0.1, inplace=True),
            nn.Conv3d(out_ch, out_ch, 3, padding=1, bias=False),
            nn.InstanceNorm3d(out_ch),
            nn.LeakyReLU(0.1, inplace=True),
        )
    def forward(self, x):
        return self.net(x)

class UNet3D(nn.Module):
    def __init__(self, in_channels=1, out_channels=1, base=32):
        super().__init__()
        self.enc1 = DoubleConv3D(in_channels, base)
        self.pool1 = nn.MaxPool3d(2)
        self.enc2 = DoubleConv3D(base, base*2)
        self.pool2 = nn.MaxPool3d(2)
        self.enc3 = DoubleConv3D(base*2, base*4)
        self.pool3 = nn.MaxPool3d(2)
        self.bottleneck = DoubleConv3D(base*4, base*8)

        self.up3 = nn.ConvTranspose3d(base*8, base*4, 2, stride=2)
        self.dec3 = DoubleConv3D(base*8, base*4)
        self.up2 = nn.ConvTranspose3d(base*4, base*2, 2, stride=2)
        self.dec2 = DoubleConv3D(base*4, base*2)
        self.up1 = nn.ConvTranspose3d(base*2, base, 2, stride=2)
        self.dec1 = DoubleConv3D(base*2, base)

        self.out = nn.Conv3d(base, out_channels, 1)

    # 모델에서 match_size를 통해
    def forward(self, x):
        e1 = self.enc1(x)
        e2 = self.enc2(self.pool1(e1))
        e3 = self.enc3(self.pool2(e2))
        b  = self.bottleneck(self.pool3(e3))

        d3 = self.up3(b)
        d3 = match_size(d3, e3)              # ✅ 추가
        d3 = self.dec3(torch.cat([d3, e3], dim=1))

        d2 = self.up2(d3)
        d2 = match_size(d2, e2)              # ✅ 추가
        d2 = self.dec2(torch.cat([d2, e2], dim=1))

        d1 = self.up1(d2)
        d1 = match_size(d1, e1)              # ✅ 추가
        d1 = self.dec1(torch.cat([d1, e1], dim=1))

        return self.out(d1)  # logits

# %%
class DiceLoss(nn.Module):
    def __init__(self, smooth=1.0):
        super().__init__()
        self.smooth = smooth

    def forward(self, logits, targets):
        # logits: (B,1,H,W,D), targets: (B,1,H,W,D) with {0,1}
        probs = torch.sigmoid(logits)
        targets = targets.float()
        dims = (2,3,4)

        intersection = (probs * targets).sum(dims)
        union = probs.sum(dims) + targets.sum(dims)
        dice = (2.0 * intersection + self.smooth) / (union + self.smooth)
        return 1.0 - dice.mean()

@torch.no_grad()
def dice_score(logits, targets, thr=0.5, smooth=1.0):
    probs = torch.sigmoid(logits)
    preds = (probs > thr).float()
    targets = targets.float()
    dims = (2,3,4)

    intersection = (preds * targets).sum(dims)
    union = preds.sum(dims) + targets.sum(dims)
    dice = (2.0 * intersection + smooth) / (union + smooth)
    return dice.mean().item()

class SoftDiceLossMulti(nn.Module):
    def __init__(self, num_classes, smooth=1.0, ignore_index=None):
        super().__init__()
        self.num_classes = num_classes
        self.smooth = smooth
        self.ignore_index = ignore_index

    def forward(self, logits, targets):
        probs = F.softmax(logits, dim=1)  # (B,C,H,W,D)
        targets_oh = F.one_hot(targets, num_classes=self.num_classes).permute(0,4,1,2,3).float()

        dims = (2,3,4)
        inter = (probs * targets_oh).sum(dims)
        union = probs.sum(dims) + targets_oh.sum(dims)
        dice = (2*inter + self.smooth) / (union + self.smooth)  # (B,C)

        if self.ignore_index is not None:
            keep = [c for c in range(self.num_classes) if c != self.ignore_index]
            dice = dice[:, keep]

        return 1 - dice.mean()

@torch.no_grad()
def dice_score_mc(logits, targets, num_classes=2, ignore_index=0, smooth=1.0):
    pred = logits.argmax(dim=1)  # (B,H,W,D)
    dices = []
    for c in range(num_classes):
        if c == ignore_index:
            continue
        p = (pred == c).float()
        t = (targets == c).float()
        inter = (p*t).sum()
        union = p.sum() + t.sum()
        dices.append(((2*inter + smooth)/(union + smooth)).item())
    return float(sum(dices)/max(len(dices),1))

# %%
from tqdm.notebook import tqdm
import torch

NUM_CLASSES = 3
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("device:", device)

model = UNet3D(in_channels=1, out_channels=NUM_CLASSES, base=32).to(device)

ce   = nn.CrossEntropyLoss()                         # ✅ 멀티클래스용
dice = SoftDiceLossMulti(NUM_CLASSES, ignore_index=0) # 배경(0) dice 제외 추천

optimizer = torch.optim.AdamW(model.parameters(), lr=2e-4, weight_decay=1e-4)
scaler = torch.cuda.amp.GradScaler(enabled=(device.type == "cuda"))

def run_one_epoch(loader, train=True):
    model.train(train)
    total_loss = 0.0
    total_dice = 0.0
    n = 0

    for x, y in tqdm(loader):
        x = x.to(device, non_blocking=True)  # (B,1,H,W,D)

        y = y.to(device, non_blocking=True)  # (B,H,W,D) long expected
        if y.ndim == 5:                      # 혹시 (B,1,H,W,D)로 들어오면
            y = y.squeeze(1)
        y = y.long()

        with torch.cuda.amp.autocast(enabled=(device.type == "cuda")):
            logits = model(x)                # (B,2,H,W,D)
            loss_ce = ce(logits, y)
            loss_dice = dice(logits, y)
            loss = 0.5 * loss_ce + 0.5 * loss_dice

        if train:
            optimizer.zero_grad(set_to_none=True)
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

        bs = x.size(0)
        total_loss += loss.item() * bs
        total_dice += dice_score_mc(logits.detach(), y, num_classes=NUM_CLASSES, ignore_index=0) * bs
        n += bs

    return total_loss / n, total_dice / n

best_val = -1.0
save_path = "/content/drive/MyDrive/project_2/best_unet3d_mc2.pth"

epochs = 30
for epoch in tqdm(range(1, epochs + 1)):
    tr_loss, tr_dice = run_one_epoch(train_loader, train=True)
    va_loss, va_dice = run_one_epoch(val_loader, train=False)

    print(f"[{epoch:02d}/{epochs}] "
          f"train loss={tr_loss:.4f}, dice={tr_dice:.4f} | "
          f"val loss={va_loss:.4f}, dice={va_dice:.4f}")

    if va_dice > best_val:
        best_val = va_dice
        torch.save(
            {"model": model.state_dict(),
             "optimizer": optimizer.state_dict(),
             "epoch": epoch,
             "val_dice": best_val},
            save_path
        )
        print(f"  ✅ saved best -> {save_path} (val_dice={best_val:.4f})")
# Out:
# device: cuda
# /tmp/ipython-input-2027331528.py:14: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=(device.type == "cuda"))
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/104 [00:00<?, ?it/s]
# /tmp/ipython-input-2027331528.py:30: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=(device.type == "cuda")):
#   0%|          | 0/13 [00:00<?, ?it/s]
# [01/30] train loss=0.9680, dice=0.0489 | val loss=0.8610, dice=0.1490
#   ✅ saved best -> /content/drive/MyDrive/project_2/best_unet3d_mc2.pth (val_dice=0.1490)
#   0%|          | 0/104 [00:00<?, ?it/s]
#   0%|          | 0/13 [00:00<?, ?it/s]
# [02/30] train loss=0.7972, dice=0.4847 | val loss=0.7392, dice=0.7303
#   ✅ saved best -> /content/drive/MyDrive/project_2/best_unet3d_mc2.pth (val_dice=0.7303)
#   0%|          | 0/104 [00:00<?, ?it/s]
#   0%|          | 0/13 [00:00<?, ?it/s]
# [03/30] train loss=0.6979, dice=0.7855 | val loss=0.6619, dice=0.7947
#   ✅ saved best -> /content/drive/MyDrive/project_2/best_unet3d_mc2.pth (val_dice=0.7947)
#   0%|          | 0/104 [00:00<?, ?it/s]
#   0%|          | 0/13 [00:00<?, ?it/s]
# [04/30] train loss=0.6359, dice=0.8192 | val loss=0.6128, dice=0.8256
#   ✅ saved best -> /content/drive/MyDrive/project_2/best_unet3d_mc2.pth (val_dice=0.8256)
#   0%|          | 0/104 [00:00<?, ?it/s]
#   0%|          | 0/13 [00:00<?, ?it/s]
# [05/30] train loss=0.5946, dice=0.8314 | val loss=0.5780, dice=0.8242
#   0%|          | 0/104 [00:00<?, ?it/s]
#   0%|          | 0/13 [00:00<?, ?it/s]
# [06/30] train loss=0.5641, dice=0.8366 | val loss=0.5510, dice=0.8233
#   0%|          | 0/104 [00:00<?, ?it/s]
#   0%|          | 0/13 [00:00<?, ?it/s]
# [07/30] train loss=0.5395, dice=0.8406 | val loss=0.5288, dice=0.8330
#   ✅ saved best -> /content/drive/MyDrive/project_2/best_unet3d_mc2.pth (val_dice=0.8330)
#   0%|          | 0/104 [00:00<?, ?it/s]
#   0%|          | 0/13 [00:00<?, ?it/s]
# [08/30] train loss=0.5182, dice=0.8436 | val loss=0.5090, dice=0.8242
#   0%|          | 0/104 [00:00<?, ?it/s]
#   0%|          | 0/13 [00:00<?, ?it/s]
# [09/30] train loss=0.4983, dice=0.8483 | val loss=0.4895, dice=0.8168
#   0%|          | 0/104 [00:00<?, ?it/s]
#   0%|          | 0/13 [00:00<?, ?it/s]
# [10/30] train loss=0.4784, dice=0.8483 | val loss=0.4691, dice=0.8182
#   0%|          | 0/104 [00:00<?, ?it/s]
#   0%|          | 0/13 [00:00<?, ?it/s]
# [11/30] train loss=0.4562, dice=0.8527 | val loss=0.4457, dice=0.8353
#   ✅ saved best -> /content/drive/MyDrive/project_2/best_unet3d_mc2.pth (val_dice=0.8353)
#   0%|          | 0/104 [00:00<?, ?it/s]
#   0%|          | 0/13 [00:00<?, ?it/s]
# [12/30] train loss=0.4298, dice=0.8578 | val loss=0.4170, dice=0.8469
#   ✅ saved best -> /content/drive/MyDrive/project_2/best_unet3d_mc2.pth (val_dice=0.8469)
#   0%|          | 0/104 [00:00<?, ?it/s]
#   0%|          | 0/13 [00:00<?, ?it/s]
# [13/30] train loss=0.3944, dice=0.8663 | val loss=0.3756, dice=0.8341
#   0%|          | 0/104 [00:00<?, ?it/s]
#   0%|          | 0/13 [00:00<?, ?it/s]
# [14/30] train loss=0.3467, dice=0.8762 | val loss=0.3239, dice=0.8437
#   0%|          | 0/104 [00:00<?, ?it/s]
#   0%|          | 0/13 [00:00<?, ?it/s]
# [15/30] train loss=0.2910, dice=0.8856 | val loss=0.2669, dice=0.8606
#   ✅ saved best -> /content/drive/MyDrive/project_2/best_unet3d_mc2.pth (val_dice=0.8606)
#   0%|          | 0/104 [00:00<?, ?it/s]
#   0%|          | 0/13 [00:00<?, ?it/s]
# [16/30] train loss=0.2297, dice=0.8978 | val loss=0.2111, dice=0.8626
#   ✅ saved best -> /content/drive/MyDrive/project_2/best_unet3d_mc2.pth (val_dice=0.8626)
#   0%|          | 0/104 [00:00<?, ?it/s]
#   0%|          | 0/13 [00:00<?, ?it/s]
# [17/30] train loss=0.1784, dice=0.9050 | val loss=0.1694, dice=0.8721
#   ✅ saved best -> /content/drive/MyDrive/project_2/best_unet3d_mc2.pth (val_dice=0.8721)
#   0%|          | 0/104 [00:00<?, ?it/s]
#   0%|          | 0/13 [00:00<?, ?it/s]
# [18/30] train loss=0.1415, dice=0.9118 | val loss=0.1424, dice=0.8792
#   ✅ saved best -> /content/drive/MyDrive/project_2/best_unet3d_mc2.pth (val_dice=0.8792)
#   0%|          | 0/104 [00:00<?, ?it/s]
#   0%|          | 0/13 [00:00<?, ?it/s]
# [19/30] train loss=0.1179, dice=0.9126 | val loss=0.1248, dice=0.8761
#   0%|          | 0/104 [00:00<?, ?it/s]
#   0%|          | 0/13 [00:00<?, ?it/s]
# [20/30] train loss=0.1004, dice=0.9166 | val loss=0.1114, dice=0.8779
#   0%|          | 0/104 [00:00<?, ?it/s]
#   0%|          | 0/13 [00:00<?, ?it/s]
# [21/30] train loss=0.0871, dice=0.9213 | val loss=0.1037, dice=0.8776
#   0%|          | 0/104 [00:00<?, ?it/s]
#   0%|          | 0/13 [00:00<?, ?it/s]
# [22/30] train loss=0.0771, dice=0.9251 | val loss=0.0972, dice=0.8761
#   0%|          | 0/104 [00:00<?, ?it/s]
#   0%|          | 0/13 [00:00<?, ?it/s]
# [23/30] train loss=0.0694, dice=0.9285 | val loss=0.0918, dice=0.8770
#   0%|          | 0/104 [00:00<?, ?it/s]
#   0%|          | 0/13 [00:00<?, ?it/s]
# [24/30] train loss=0.0641, dice=0.9300 | val loss=0.0880, dice=0.8777
#   0%|          | 0/104 [00:00<?, ?it/s]
#   0%|          | 0/13 [00:00<?, ?it/s]
# [25/30] train loss=0.0588, dice=0.9332 | val loss=0.0854, dice=0.8764
#   0%|          | 0/104 [00:00<?, ?it/s]
#   0%|          | 0/13 [00:00<?, ?it/s]
# [26/30] train loss=0.0555, dice=0.9338 | val loss=0.0833, dice=0.8761
#   0%|          | 0/104 [00:00<?, ?it/s]
#   0%|          | 0/13 [00:00<?, ?it/s]
# [27/30] train loss=0.0505, dice=0.9390 | val loss=0.0812, dice=0.8765
#   0%|          | 0/104 [00:00<?, ?it/s]
#   0%|          | 0/13 [00:00<?, ?it/s]
# [28/30] train loss=0.0464, dice=0.9430 | val loss=0.0803, dice=0.8749
#   0%|          | 0/104 [00:00<?, ?it/s]
#   0%|          | 0/13 [00:00<?, ?it/s]
# [29/30] train loss=0.0427, dice=0.9470 | val loss=0.0786, dice=0.8756
#   0%|          | 0/104 [00:00<?, ?it/s]
#   0%|          | 0/13 [00:00<?, ?it/s]
# [30/30] train loss=0.0397, dice=0.9501 | val loss=0.0786, dice=0.8735

# %%
import torch
import numpy as np
import nibabel as nib
import os

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

ckpt = torch.load("/content/drive/MyDrive/project_2/best_unet3d_mc2.pth", map_location=device)
model.load_state_dict(ckpt["model"])
model.eval()

print("Loaded model from epoch:", ckpt["epoch"])
# Out:
# Loaded model from epoch: 18

# %%
def zscore_nonzero_np(x):
    x = x.astype(np.float32)
    m = x != 0
    if m.sum() < 10:
        return (x - x.mean()) / (x.std() + 1e-8)
    mean = x[m].mean()
    std  = x[m].std() + 1e-8
    return (x - mean) / std

# %%
@torch.no_grad()
def sliding_window_predict_3d(
    model,
    volume_np,
    patch_size=(96,96,96),
    overlap=0.5,
    device="cuda"
):
    """
    volume_np: (H,W,D)
    return: prob_map (H,W,D) in [0,1]
    """
    model.eval()

    H, W, D = volume_np.shape
    ph, pw, pd = patch_size

    sh = max(1, int(ph * (1 - overlap)))
    sw = max(1, int(pw * (1 - overlap)))
    sd = max(1, int(pd * (1 - overlap)))

    prob_sum = np.zeros((H, W, D), dtype=np.float32)
    count    = np.zeros((H, W, D), dtype=np.float32)

    xs = list(range(0, max(1, H - ph + 1), sh))
    ys = list(range(0, max(1, W - pw + 1), sw))
    zs = list(range(0, max(1, D - pd + 1), sd))
    if xs[-1] != H - ph: xs.append(H - ph)
    if ys[-1] != W - pw: ys.append(W - pw)
    if zs[-1] != D - pd: zs.append(D - pd)

    for x1 in xs:
        for y1 in ys:
            for z1 in zs:
                patch = volume_np[x1:x1+ph, y1:y1+pw, z1:z1+pd]
                x_t = torch.tensor(
                    patch[None, None, ...],
                    dtype=torch.float32,
                    device=device
                )

                with torch.cuda.amp.autocast(enabled=(device=="cuda")):
                    logits = model(x_t)
                    probs = torch.sigmoid(logits)[0,0].cpu().numpy()

                prob_sum[x1:x1+ph, y1:y1+pw, z1:z1+pd] += probs
                count[x1:x1+ph, y1:y1+pw, z1:z1+pd] += 1.0

    return prob_sum / np.maximum(count, 1e-8)

# %%
import numpy as np
import nibabel as nib
import torch
import torch.nn.functional as F

def zscore_nonzero_np(x):
    x = x.astype(np.float32)
    m = x != 0
    if m.sum() < 10:
        return (x - x.mean()) / (x.std() + 1e-8)
    mean = x[m].mean()
    std  = x[m].std() + 1e-8
    return (x - mean) / std

@torch.no_grad()
def sliding_window_predict_auto(model, volume_np, patch_size=(96,96,96), overlap=0.5, device=None):
    """
    return:
      pred: (H,W,D) uint8 class map (binary면 0/1, multi면 0..C-1)
      prob_or_none: binary면 (H,W,D) prob map(float32), multi면 None(필요시 확장 가능)
    """
    model.eval()
    if device is None:
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # out_channels 추정
    C = None
    if hasattr(model, "out") and hasattr(model.out, "out_channels"):
        C = model.out.out_channels
    else:
        # fallback: 한 번 forward 해서 채널 수 확인
        dummy = torch.zeros(1,1,*patch_size, device=device)
        C = model(dummy).shape[1]

    H, W, D = volume_np.shape
    ph, pw, pd = patch_size

    sh = max(1, int(ph * (1 - overlap)))
    sw = max(1, int(pw * (1 - overlap)))
    sd = max(1, int(pd * (1 - overlap)))

    # 시작 인덱스들 (끝까지 덮도록)
    xs = list(range(0, max(1, H - ph + 1), sh))
    ys = list(range(0, max(1, W - pw + 1), sw))
    zs = list(range(0, max(1, D - pd + 1), sd))
    if xs[-1] != H - ph: xs.append(H - ph)
    if ys[-1] != W - pw: ys.append(W - pw)
    if zs[-1] != D - pd: zs.append(D - pd)

    # 누적 버퍼
    if C == 1:
        prob_sum = np.zeros((H, W, D), dtype=np.float32)
    else:
        prob_sum = np.zeros((C, H, W, D), dtype=np.float32)
    count = np.zeros((H, W, D), dtype=np.float32)

    for x1 in xs:
        for y1 in ys:
            for z1 in zs:
                patch = volume_np[x1:x1+ph, y1:y1+pw, z1:z1+pd]
                x_t = torch.tensor(patch[None, None, ...], dtype=torch.float32, device=device)

                with torch.cuda.amp.autocast(enabled=(device.type=="cuda")):
                    logits = model(x_t)  # (1,C,ph,pw,pd)

                    if C == 1:
                        probs = torch.sigmoid(logits)[0,0].float().cpu().numpy()  # (ph,pw,pd)
                        prob_sum[x1:x1+ph, y1:y1+pw, z1:z1+pd] += probs
                    else:
                        probs = F.softmax(logits, dim=1)[0].float().cpu().numpy()  # (C,ph,pw,pd)
                        prob_sum[:, x1:x1+ph, y1:y1+pw, z1:z1+pd] += probs

                count[x1:x1+ph, y1:y1+pw, z1:z1+pd] += 1.0

    if C == 1:
        prob_map = prob_sum / np.maximum(count, 1e-8)
        pred = (prob_map > 0.5).astype(np.uint8)
        return pred, prob_map
    else:
        prob_map = prob_sum / np.maximum(count[None, ...], 1e-8)
        pred = prob_map.argmax(axis=0).astype(np.uint8)
        return pred, None

# %%
def best_slice_index_from_gt(gt, axis=2):
    # gt: (H,W,D) 값>0인 면적이 최대인 slice index
    if axis == 0:
        areas = (gt > 0).sum(axis=(1,2))
    elif axis == 1:
        areas = (gt > 0).sum(axis=(0,2))
    else:
        areas = (gt > 0).sum(axis=(0,1))
    return int(np.argmax(areas))

# %%
import matplotlib.pyplot as plt

def visualize_case(img_np, gt_np, pred_np, axis=2, slice_idx=None, title_prefix=""):
    """
    img_np: (H,W,D)
    gt_np:  (H,W,D) 0/1 or 0/1/2...
    pred_np:(H,W,D) 0/1 or 0/1/2...
    """
    if slice_idx is None:
        slice_idx = best_slice_index_from_gt(gt_np, axis=axis)

    if axis == 0:
        img2 = img_np[slice_idx, :, :]
        gt2  = gt_np[slice_idx, :, :]
        pr2  = pred_np[slice_idx, :, :]
    elif axis == 1:
        img2 = img_np[:, slice_idx, :]
        gt2  = gt_np[:, slice_idx, :]
        pr2  = pred_np[:, slice_idx, :]
    else:
        img2 = img_np[:, :, slice_idx]
        gt2  = gt_np[:, :, slice_idx]
        pr2  = pred_np[:, :, slice_idx]

    plt.figure(figsize=(14,4))

    plt.subplot(1,3,1)
    plt.title(f"{title_prefix}Image (axis={axis}, idx={slice_idx})")
    plt.imshow(img2, cmap="gray")
    plt.axis("off")

    plt.subplot(1,3,2)
    plt.title("GT (Green) vs Pred (Red)")
    plt.imshow(img2, cmap="gray")
    # GT: green
    plt.imshow((gt2 > 0).astype(np.float32), alpha=0.35, cmap="Greens")
    # Pred: red
    plt.imshow((pr2 > 0).astype(np.float32), alpha=0.35, cmap="Reds")
    plt.axis("off")

    plt.subplot(1,3,3)
    plt.title("Errors: FP=Red, FN=Blue")
    fp = ((pr2 > 0) & (gt2 == 0)).astype(np.float32)
    fn = ((pr2 == 0) & (gt2 > 0)).astype(np.float32)
    plt.imshow(img2, cmap="gray")
    plt.imshow(fp, alpha=0.45, cmap="Reds")
    plt.imshow(fn, alpha=0.45, cmap="Blues")
    plt.axis("off")

    plt.tight_layout()
    plt.show()

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device).eval()  # 이미 로드되어 있다고 가정

case_idx = 10  # 보고 싶은 val index

img_nii = nib.load(val_imgs[case_idx])
lab_nii = nib.load(val_labs[case_idx])

img = np.squeeze(img_nii.get_fdata()).astype(np.float32)
gt  = np.squeeze(lab_nii.get_fdata()).astype(np.int16)

img_norm = zscore_nonzero_np(img)

pred, prob = sliding_window_predict_auto(
    model,
    img_norm,
    patch_size=(96,96,96),
    overlap=0.5,
    device=device
)

# GT가 0/1/2면 그대로 비교 가능, binary면 (gt>0)으로 통일하고 싶으면 아래 한 줄:
# gt = (gt > 0).astype(np.uint8)

visualize_case(img, gt, pred, axis=2, slice_idx=None, title_prefix=f"VAL[{case_idx}] ")
# Out:
# /tmp/ipython-input-627015666.py:63: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=(device.type=="cuda")):

# %%
test_img_paths = sorted(glob("/content/Task04_Hippocampus/imagesTs/*.nii.gz"))

out_dir = "/content/test_predictions"
os.makedirs(out_dir, exist_ok=True)

for i, img_path in enumerate(test_img_paths):
    img_nii = nib.load(img_path)
    img = np.squeeze(img_nii.get_fdata()).astype(np.float32)

    img_norm = zscore_nonzero_np(img)

    prob = sliding_window_predict_3d(
        model,
        img_norm,
        patch_size=(96,96,96),
        overlap=0.5,
        device=device
    )

    pred_bin = (prob > 0.5).astype(np.uint8)

    pred_nii = nib.Nifti1Image(
        pred_bin,
        affine=img_nii.affine,
        header=img_nii.header
    )

    name = os.path.basename(img_path).replace(".nii.gz", "_pred.nii.gz")
    nib.save(pred_nii, os.path.join(out_dir, name))

    print(f"[{i+1}/{len(test_img_paths)}] saved:", name)
# Out:
# /tmp/ipython-input-2798986260.py:42: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=(device=="cuda")):
# [1/130] saved: hippocampus_002_pred.nii.gz
# [2/130] saved: hippocampus_005_pred.nii.gz
# [3/130] saved: hippocampus_009_pred.nii.gz
# [4/130] saved: hippocampus_010_pred.nii.gz
# [5/130] saved: hippocampus_012_pred.nii.gz
# [6/130] saved: hippocampus_013_pred.nii.gz
# [7/130] saved: hippocampus_016_pred.nii.gz
# [8/130] saved: hippocampus_018_pred.nii.gz
# [9/130] saved: hippocampus_021_pred.nii.gz
# [10/130] saved: hippocampus_022_pred.nii.gz
# [11/130] saved: hippocampus_027_pred.nii.gz
# [12/130] saved: hippocampus_028_pred.nii.gz
# [13/130] saved: hippocampus_029_pred.nii.gz
# [14/130] saved: hippocampus_030_pred.nii.gz
# [15/130] saved: hippocampus_043_pred.nii.gz
# [16/130] saved: hippocampus_047_pred.nii.gz
# [17/130] saved: hippocampus_054_pred.nii.gz
# [18/130] saved: hippocampus_055_pred.nii.gz
# [19/130] saved: hippocampus_059_pred.nii.gz
# [20/130] saved: hippocampus_061_pred.nii.gz
# [21/130] saved: hippocampus_062_pred.nii.gz
# [22/130] saved: hippocampus_063_pred.nii.gz
# [23/130] saved: hippocampus_066_pred.nii.gz
# [24/130] saved: hippocampus_069_pred.nii.gz
# [25/130] saved: hippocampus_071_pred.nii.gz
# [26/130] saved: hippocampus_072_pred.nii.gz
# [27/130] saved: hippocampus_073_pred.nii.gz
# [28/130] saved: hippocampus_076_pred.nii.gz
# [29/130] saved: hippocampus_078_pred.nii.gz
# [30/130] saved: hippocampus_079_pred.nii.gz
# [31/130] saved: hippocampus_080_pred.nii.gz
# [32/130] saved: hippocampus_081_pred.nii.gz
# [33/130] saved: hippocampus_082_pred.nii.gz
# [34/130] saved: hippocampus_100_pred.nii.gz
# [35/130] saved: hippocampus_103_pred.nii.gz
# [36/130] saved: hippocampus_110_pred.nii.gz
# [37/130] saved: hippocampus_111_pred.nii.gz
# [38/130] saved: hippocampus_112_pred.nii.gz
# [39/130] saved: hippocampus_113_pred.nii.gz
# [40/130] saved: hippocampus_115_pred.nii.gz
# [41/130] saved: hippocampus_116_pred.nii.gz
# [42/130] saved: hippocampus_117_pred.nii.gz
# [43/130] saved: hippocampus_118_pred.nii.gz
# [44/130] saved: hippocampus_119_pred.nii.gz
# [45/130] saved: hippocampus_120_pred.nii.gz
# [46/130] saved: hippocampus_121_pred.nii.gz
# [47/130] saved: hippocampus_122_pred.nii.gz
# [48/130] saved: hippocampus_128_pred.nii.gz
# [49/130] saved: hippocampus_129_pred.nii.gz
# [50/130] saved: hippocampus_131_pred.nii.gz
# [51/130] saved: hippocampus_134_pred.nii.gz
# [52/130] saved: hippocampus_137_pred.nii.gz
# [53/130] saved: hippocampus_139_pred.nii.gz
# [54/130] saved: hippocampus_140_pred.nii.gz
# [55/130] saved: hippocampus_147_pred.nii.gz
# [56/130] saved: hippocampus_151_pred.nii.gz
# [57/130] saved: hippocampus_153_pred.nii.gz
# [58/130] saved: hippocampus_159_pred.nii.gz
# [59/130] saved: hippocampus_167_pred.nii.gz
# [60/130] saved: hippocampus_168_pred.nii.gz
# [61/130] saved: hippocampus_179_pred.nii.gz
# [62/130] saved: hippocampus_182_pred.nii.gz
# [63/130] saved: hippocampus_183_pred.nii.gz
# [64/130] saved: hippocampus_186_pred.nii.gz
# [65/130] saved: hippocampus_187_pred.nii.gz
# [66/130] saved: hippocampus_191_pred.nii.gz
# [67/130] saved: hippocampus_192_pred.nii.gz
# [68/130] saved: hippocampus_196_pred.nii.gz
# [69/130] saved: hippocampus_198_pred.nii.gz
# [70/130] saved: hippocampus_200_pred.nii.gz
# [71/130] saved: hippocampus_201_pred.nii.gz
# [72/130] saved: hippocampus_202_pred.nii.gz
# [73/130] saved: hippocampus_206_pred.nii.gz
# [74/130] saved: hippocampus_208_pred.nii.gz
# [75/130] saved: hippocampus_209_pred.nii.gz
# [76/130] saved: hippocampus_211_pred.nii.gz
# [77/130] saved: hippocampus_213_pred.nii.gz
# [78/130] saved: hippocampus_214_pred.nii.gz
# [79/130] saved: hippocampus_218_pred.nii.gz
# [80/130] saved: hippocampus_237_pred.nii.gz
# [81/130] saved: hippocampus_239_pred.nii.gz
# [82/130] saved: hippocampus_240_pred.nii.gz
# [83/130] saved: hippocampus_241_pred.nii.gz
# [84/130] saved: hippocampus_246_pred.nii.gz
# [85/130] saved: hippocampus_247_pred.nii.gz
# [86/130] saved: hippocampus_254_pred.nii.gz
# [87/130] saved: hippocampus_255_pred.nii.gz
# [88/130] saved: hippocampus_256_pred.nii.gz
# [89/130] saved: hippocampus_258_pred.nii.gz
# [90/130] saved: hippocampus_262_pred.nii.gz
# [91/130] saved: hippocampus_266_pred.nii.gz
# [92/130] saved: hippocampus_267_pred.nii.gz
# [93/130] saved: hippocampus_270_pred.nii.gz
# [94/130] saved: hippocampus_271_pred.nii.gz
# [95/130] saved: hippocampus_272_pred.nii.gz
# [96/130] saved: hippocampus_273_pred.nii.gz
# [97/130] saved: hippocampus_275_pred.nii.gz
# [98/130] saved: hippocampus_278_pred.nii.gz
# [99/130] saved: hippocampus_281_pred.nii.gz
# [100/130] saved: hippocampus_283_pred.nii.gz
# [101/130] saved: hippocampus_284_pred.nii.gz
# [102/130] saved: hippocampus_285_pred.nii.gz
# [103/130] saved: hippocampus_291_pred.nii.gz
# [104/130] saved: hippocampus_293_pred.nii.gz
# [105/130] saved: hippocampus_306_pred.nii.gz
# [106/130] saved: hippocampus_307_pred.nii.gz
# [107/130] saved: hippocampus_312_pred.nii.gz
# [108/130] saved: hippocampus_313_pred.nii.gz
# [109/130] saved: hippocampus_315_pred.nii.gz
# [110/130] saved: hippocampus_323_pred.nii.gz
# [111/130] saved: hippocampus_324_pred.nii.gz
# [112/130] saved: hippocampus_339_pred.nii.gz
# [113/130] saved: hippocampus_342_pred.nii.gz
# [114/130] saved: hippocampus_344_pred.nii.gz
# [115/130] saved: hippocampus_346_pred.nii.gz
# [116/130] saved: hippocampus_347_pred.nii.gz
# [117/130] saved: hippocampus_348_pred.nii.gz
# [118/130] saved: hippocampus_357_pred.nii.gz
# [119/130] saved: hippocampus_362_pred.nii.gz
# [120/130] saved: hippocampus_364_pred.nii.gz
# [121/130] saved: hippocampus_365_pred.nii.gz
# [122/130] saved: hippocampus_369_pred.nii.gz
# [123/130] saved: hippocampus_371_pred.nii.gz
# [124/130] saved: hippocampus_377_pred.nii.gz
# [125/130] saved: hippocampus_379_pred.nii.gz
# [126/130] saved: hippocampus_382_pred.nii.gz
# [127/130] saved: hippocampus_384_pred.nii.gz
# [128/130] saved: hippocampus_388_pred.nii.gz
# [129/130] saved: hippocampus_391_pred.nii.gz
# [130/130] saved: hippocampus_392_pred.nii.gz

# %%
import matplotlib.pyplot as plt

idx = 4  # 보고 싶은 test case index
img_nii = nib.load(test_img_paths[idx])
img = np.squeeze(img_nii.get_fdata())
pred = nib.load(os.path.join(
    out_dir,
    os.path.basename(test_img_paths[idx]).replace(".nii.gz", "_pred.nii.gz")
)).get_fdata()

z = img.shape[2] // 2

plt.figure(figsize=(12,4))
plt.subplot(1,3,1)
plt.title("Image")
plt.imshow(img[:,:,z], cmap="gray")
plt.axis("off")

plt.subplot(1,3,2)
plt.title("Prediction")
plt.imshow(pred[:,:,z], cmap="hot")
plt.axis("off")

plt.subplot(1,3,3)
plt.title("Overlay")
plt.imshow(img[:,:,z], cmap="gray")
plt.imshow(pred[:,:,z], cmap="Reds", alpha=0.4)
plt.axis("off")
plt.show()

# %%
import nibabel as nib

# Analyze 포맷 로드 (.hdr 또는 .img 중 하나만 지정하면 됨)
img = nib.load("/content/OAS1_0001_MR1_mpr-1_anon.hdr")

# NIfTI 저장 (자동으로 .nii.gz 생성)
nib.save(img, "/content/OAS1_0001_MR1_mpr-1_anon.nii.gz")
